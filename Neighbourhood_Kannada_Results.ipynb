# %%
# !pip install -U linktransformer
# Out:
# Collecting linktransformer
#   Downloading linktransformer-0.1.12-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from linktransformer) (1.2.2)
# Collecting faiss-cpu (from linktransformer)
#   Downloading faiss_cpu-1.7.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 52.5 MB/s eta 0:00:00
# Collecting hdbscan (from linktransformer)
#   Downloading hdbscan-0.8.33.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 101.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from linktransformer) (3.2.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from linktransformer) (2.1.0+cu121)
# Collecting sentence-transformers (from linktransformer)
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 13.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from linktransformer) (4.35.2)
# Collecting wandb (from linktransformer)
#   Downloading wandb-0.16.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 94.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from linktransformer) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from linktransformer) (1.5.3)
# Collecting openai (from linktransformer)
#   Downloading openai-1.6.1-py3-none-any.whl (225 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 225.4/225.4 kB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (from linktransformer) (3.1.2)
# Collecting datasets (from linktransformer)
#   Downloading datasets-2.16.0-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 53.7 MB/s eta 0:00:00
# Collecting accelerate (from linktransformer)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 31.5 MB/s eta 0:00:00
# Collecting evaluate (from linktransformer)
#   Downloading evaluate-0.4.1-py3-none-any.whl (84 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate->linktransformer) (23.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate->linktransformer) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate->linktransformer) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate->linktransformer) (0.19.4)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate->linktransformer) (0.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->linktransformer) (2.1.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->linktransformer) (10.0.1)
# Collecting pyarrow-hotfix (from datasets->linktransformer)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->linktransformer)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets->linktransformer) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets->linktransformer) (4.66.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->linktransformer) (3.4.1)
# Collecting multiprocess (from datasets->linktransformer)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->linktransformer) (3.9.1)
# Collecting responses<0.19 (from evaluate->linktransformer)
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting cython<3,>=0.27 (from hdbscan->linktransformer)
#   Using cached Cython-0.29.37-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (1.9 MB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan->linktransformer) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan->linktransformer) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->linktransformer) (3.2.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai->linktransformer) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai->linktransformer) (1.7.0)
# Collecting httpx<1,>=0.23.0 (from openai->linktransformer)
#   Downloading httpx-0.26.0-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai->linktransformer) (1.10.13)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai->linktransformer) (1.3.0)
# Collecting typing-extensions (from torch->linktransformer)
#   Downloading typing_extensions-4.9.0-py3-none-any.whl (32 kB)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl->linktransformer) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->linktransformer) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->linktransformer) (2023.3.post1)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->linktransformer) (0.16.0+cu121)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->linktransformer) (3.8.1)
# Collecting sentencepiece (from sentence-transformers->linktransformer)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.7 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->linktransformer) (2023.6.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers->linktransformer) (0.15.0)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb->linktransformer) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb->linktransformer)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 24.1 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0 (from wandb->linktransformer)
#   Downloading sentry_sdk-1.39.1-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 33.3 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb->linktransformer)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb->linktransformer)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb->linktransformer) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb->linktransformer) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb->linktransformer) (3.20.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->linktransformer) (3.6)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai->linktransformer) (1.2.0)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb->linktransformer) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->linktransformer) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb->linktransformer)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai->linktransformer) (2023.11.17)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai->linktransformer)
#   Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 11.5 MB/s eta 0:00:00
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx<1,>=0.23.0->openai->linktransformer)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->linktransformer) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets->linktransformer) (2.0.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->linktransformer) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->linktransformer) (1.3.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers->linktransformer) (9.4.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb->linktransformer)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: hdbscan, sentence-transformers
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.33-cp310-cp310-linux_x86_64.whl size=3039297 sha256=3d3ba7c96d4641e2adb34ce3bc9acb3a6105bba905ac61c504b8793317d08613
#   Stored in directory: /root/.cache/pip/wheels/75/0b/3b/dc4f60b7cc455efaefb62883a7483e76f09d06ca81cf87d610
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125923 sha256=ade760e5b4840f3bafc9f6d91b51609b34bee784912ee697d61ac1111d3d1f12
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built hdbscan sentence-transformers
# Installing collected packages: sentencepiece, faiss-cpu, typing-extensions, smmap, setproctitle, sentry-sdk, pyarrow-hotfix, h11, docker-pycreds, dill, cython, responses, multiprocess, httpcore, gitdb, httpx, hdbscan, GitPython, accelerate, wandb, openai, datasets, sentence-transformers, evaluate, linktransformer
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.6
#     Uninstalling Cython-3.0.6:
#       Successfully uninstalled Cython-3.0.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# Successfully installed GitPython-3.1.40 accelerate-0.25.0 cython-0.29.37 datasets-2.16.0 dill-0.3.7 docker-pycreds-0.4.0 evaluate-0.4.1 faiss-cpu-1.7.4 gitdb-4.0.11 h11-0.14.0 hdbscan-0.8.33 httpcore-1.0.2 httpx-0.26.0 linktransformer-0.1.12 multiprocess-0.70.15 openai-1.6.1 pyarrow-hotfix-0.6 responses-0.18.0 sentence-transformers-2.2.2 sentencepiece-0.1.99 sentry-sdk-1.39.1 setproctitle-1.3.3 smmap-5.0.1 typing-extensions-4.9.0 wandb-0.16.1

# %%
import linktransformer as lt
import pandas as pd
import sklearn

# %%
trdf= pd.read_csv('/content/ktrain.csv')
edf= pd.read_csv('/content/keval.csv')
tdf= pd.read_csv('/content/ktest.csv')

# %%
train=trdf.drop(['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2','Household', 'Village', 'GP'],axis=1)
eval= edf.drop(['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2','Household', 'Village', 'GP'],axis=1)
test= tdf.drop(['Unnamed: 0.1', 'Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2','Household', 'Village', 'GP'],axis=1)

# %%
best_model_path,best_metric, label_map= lt.train_clf_model(train_data=train,val_data=eval,test_data=test,model="bert-base-multilingual-cased",on="Template",label_col_name="Neighbourhood",data_dir=".",
                    lr=2e-5,batch_size=8,training_args={"num_train_epochs":10},model_save_dir="test_lt_clf", weighted_loss=True,weight_list=None,
                    wandb_log=True)
# Out:
# Number of labels: 2
# Proportions of labels: [0.900952380952381, 0.09904761904761905]
# Number of labels: 2
# Proportions of labels: [0.8888888888888888, 0.1111111111111111]
# Number of labels: 2
# Proportions of labels: [0.5688888888888889, 0.4311111111111111]
# 4200 training examples
# 900 dev examples
# 900 test examples
# Generating data split: 0 examples [00:00, ? examples/s]
# tokenizer_config.json:   0%|          | 0.00/29.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# Map:   0%|          | 0/4200 [00:00<?, ? examples/s]
# Generating data split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/900 [00:00<?, ? examples/s]
# Generating data split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/900 [00:00<?, ? examples/s]
# Updating training args with:  {'num_train_epochs': 10}
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ··········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/wandb/run-20231226_084623-hqucw85x</code>
# Syncing run <strong><a href='https://wandb.ai/karnatakalocaldevelopments/topic/runs/hqucw85x' target="_blank">whole-feather-15</a></strong> to <a href='https://wandb.ai/karnatakalocaldevelopments/topic' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/karnatakalocaldevelopments/topic' target="_blank">https://wandb.ai/karnatakalocaldevelopments/topic</a>
#  View run at <a href='https://wandb.ai/karnatakalocaldevelopments/topic/runs/hqucw85x' target="_blank">https://wandb.ai/karnatakalocaldevelopments/topic/runs/hqucw85x</a>
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
#     <div>
#
#       <progress value='4144' max='5250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4144/5250 2:28:03 < 39:32, 0.47 it/s, Epoch 7.89/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>30</td>
#       <td>No log</td>
#       <td>0.711291</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>No log</td>
#       <td>0.685412</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>No log</td>
#       <td>0.743644</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>No log</td>
#       <td>0.679031</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>No log</td>
#       <td>0.702669</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>No log</td>
#       <td>0.667881</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>No log</td>
#       <td>0.685180</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>No log</td>
#       <td>0.666585</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>270</td>
#       <td>No log</td>
#       <td>0.709311</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>No log</td>
#       <td>0.670205</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>330</td>
#       <td>No log</td>
#       <td>0.667168</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>360</td>
#       <td>No log</td>
#       <td>0.709467</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>390</td>
#       <td>No log</td>
#       <td>0.668555</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>420</td>
#       <td>No log</td>
#       <td>0.680825</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>No log</td>
#       <td>0.716824</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>480</td>
#       <td>No log</td>
#       <td>0.700028</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>510</td>
#       <td>0.696900</td>
#       <td>0.675224</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>540</td>
#       <td>0.696900</td>
#       <td>0.703334</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>570</td>
#       <td>0.696900</td>
#       <td>0.686415</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.696900</td>
#       <td>0.672558</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>630</td>
#       <td>0.696900</td>
#       <td>0.710966</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>660</td>
#       <td>0.696900</td>
#       <td>0.709303</td>
#       <td>0.111111</td>
#       <td>0.111111</td>
#       <td>1.000000</td>
#       <td>0.200000</td>
#     </tr>
#     <tr>
#       <td>690</td>
#       <td>0.696900</td>
#       <td>0.666684</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>720</td>
#       <td>0.696900</td>
#       <td>0.666633</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.696900</td>
#       <td>0.689756</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>780</td>
#       <td>0.696900</td>
#       <td>0.677105</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>810</td>
#       <td>0.696900</td>
#       <td>0.671559</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>840</td>
#       <td>0.696900</td>
#       <td>0.675806</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>870</td>
#       <td>0.696900</td>
#       <td>0.666552</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.696900</td>
#       <td>0.667764</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>930</td>
#       <td>0.696900</td>
#       <td>0.672735</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>960</td>
#       <td>0.696900</td>
#       <td>0.676115</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>990</td>
#       <td>0.696900</td>
#       <td>0.674259</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1020</td>
#       <td>0.678300</td>
#       <td>0.682334</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.678300</td>
#       <td>0.666644</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1080</td>
#       <td>0.678300</td>
#       <td>0.666576</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1110</td>
#       <td>0.678300</td>
#       <td>0.673657</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1140</td>
#       <td>0.678300</td>
#       <td>0.686202</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1170</td>
#       <td>0.678300</td>
#       <td>0.681863</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.678300</td>
#       <td>0.671358</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1230</td>
#       <td>0.678300</td>
#       <td>0.676028</td>
#       <td>0.888889</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#       <td>0.000000</td>
#     </tr>
#     <tr>
#       <td>1260</td>
#       <td>0.678300</td>
#       <td>0.668375</td>
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.55k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/7.36k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/6.77k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
df_clf_output = lt.classify_rows(test, on="Template", model=best_model_path)
# Out:
# Map:   0%|          | 0/900 [00:00<?, ? examples/s]

# %%
df_clf_output = df_clf_output.reset_index(drop=True)
df_clf_output
# Out:
#      GP                                           Template clf_preds_Template
# 0     0  ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹುಮನಾಬಾದ್ ತಾಲೂಕಿನ...                  0
# 1     0  ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಯಾದಗಿರಿಯ ಪುಟ್ಪಾಕ್...                  0
# 2     0  The local development project is described as ...                  0
# 3     1  ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಅಫಜಲಪುರ ತಾಲೂಕಿನ ಮ...                  1
# 4     1  The local development project is described as ...                  1
# ..   ..                                                ...                ...
# 895   1  The local development project is described as ...                  0
# 896   0  ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹರದನಹಳ್ಳಿ ಗ್ರಾಮದಲ...                  0
# 897   0  ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಅರಸೀಕೆರೆ ತಾಲೂಕಿನ ...                  0
# 898   0  The local development project is described as ...                  0
# 899   0  The local development project is described as ...                  0
#
# [900 rows x 3 columns]

# %%
df_clf_output['clf_preds_Template']=df_clf_output['clf_preds_Template'].astype(int)

# %%
def calculate_false_positives_and_false_negatives(df_clf_output):
  fp=0 #false positive
  fn=0 #false negative
  for i in range(len(df_clf_output)):
      if df_clf_output['GP'][i]==0 and df_clf_output['clf_preds_Template'][i]==1:
         fp=fp+1
      if df_clf_output['GP'][i]==1 and df_clf_output['clf_preds_Template'][i]==0:
         fn=fn+1
  return fp,fn

# %%
false_positives, false_negatives= calculate_false_positives_and_false_negatives(df_clf_output)

# %%
print("false positives",false_positives)
print("false negatives", false_negatives)
# Out:
# false positives 24
# false negatives 37

# %%
false_negatives = []
false_positives = []
for i in range(len(df_clf_output)):
    if df_clf_output['GP'][i]==0 and df_clf_output['clf_preds_Template'][i]==1:
       false_positives.append(df_clf_output['Template'][i])
    if df_clf_output['GP'][i]==1 and df_clf_output['clf_preds_Template'][i]==0:
       false_negatives.append(df_clf_output['Template'][i])

# Printing the text of false negatives
print("False Negatives:")
for text in false_negatives:
    print(text)

# Printing the text of false positives
print("\nFalse Positives:")
for text in false_positives:
    print(text)
# Out:
# False Negatives:
# The local development project is described as "Construction of Open well at Beedu area in Keradi Gp.". It is located in village Keradi, of gram panchayat Keradi in taluk Kundapura of district Udupi. The estimated cost of the work is Rs. 400000.0. The current status of the work is described as "Completion Of Work" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "REPAIRS TO ANGANWADI(NEAR LAXMI TEMPLE)BULDING AT KARJAGI VILLAGE IN AGZALPUR TALUKA". It is located in village Karjagi, of gram panchayat Karjagi in taluk Afzalpur of district Kalaburagi. The estimated cost of the work is Rs. 50000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹುಮನಾಬಾದ್ ತಾಲೂಕಿನ ಮನ್ನಾಎಖೆಳ್ಳಿ ಗ್ರಾಮದ ಸಂಜೀವ್ ಕುಮಾರ್ ಎಚ್‌ಪೋಸ್‌ನಿಂದ ರಂಗಮ್ಮ ಮನೆವರೆಗೆ ಸಿಸಿ ಡ್ರೈನ್ ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೀದರ್ ಜಿಲ್ಲೆಯ ಹುಮನಾಬಾದ್ ತಾಲೂಕಿನ ಮನ್ನಾಎಖೆಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಮನ್ನಾಎಖೆಲ್ಲಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 50000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "PROVIDING SCHOOL WATER SUPPLY SCHEME TO L P S AT SHINGALAPUR TAKKE (SCHOOL WATER SUPPLY 2013-14) BORE WELL". It is located in village Shingalapur, of gram panchayat Lolasur in taluk Gokak of district Belagavi. The estimated cost of the work is Rs. 150000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "TFC 08032019 Repairing of openwell near Madhewada Habbastan Temple in Asnoti G.P of Karwar Taluka.". It is located in village Madhevada, of gram panchayat Asnoti in taluk Karwar of district Uttara Kannada. The estimated cost of the work is Rs. 50000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "Constn.of Basement, Cabin, fully automated WPP with stainless steel of Regular model 1000 LPH in Koppa (Indoor), Mundgod Tq. (BC Soil)". It is located in village Koppa (Indoor), of gram panchayat Indoor in taluk Mundgod of district Uttara Kannada. The estimated cost of the work is Rs. 1020000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಪಶುಸಂಗೋಪನೆ ಅಡಿಯಲ್ಲಿ ಗಿರಿರಾಜ ಪಕ್ಷಿಗಳ ವಿತರಣೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ದಕ್ಷಿಣ ಕನ್ನಡ ಜಿಲ್ಲೆಯ ಸುಳ್ಯ ತಾಲೂಕಿನ ನೆಲ್ಲೂರು ಕೆಮ್ರಾಜೆ ಗ್ರಾಮ ಪಂಚಾಯತ್ ನ ನೆಲ್ಲೂರುಕೆಮರಾಜೆ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 50000.0. ಕಾಮಗಾರಿಯ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕ್ರಿಯ ಯೋಜನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ತಿಳಿದಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ತರೂರ್ ಜಿಪಿಯಲ್ಲಿ ಬಾಲನಪಾಳ್ಯ ವಸತಿಯಲ್ಲಿ MWSS ಪುನರುಜ್ಜೀವನ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ತುಮಕೂರು ಜಿಲ್ಲೆಯ ಸಿರಾ ತಾಲೂಕಿನ ತರೂರು ಗ್ರಾಮ ಪಂಚಾಯತ್ ವ್ಯಾಪ್ತಿಯ ಬಾಲನಪಾಳ್ಯ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 300000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಎಚ್‌ಡಿ ಕೋಟೆ ತಾಲೂಕಿನ ಅಂಕನಾಥಪುರ ಗ್ರಾಮದಲ್ಲಿ ನೀರು ಸರಬರಾಜು ಸೌಲಭ್ಯವನ್ನು ಒದಗಿಸುವುದು" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಮೈಸೂರು ಜಿಲ್ಲೆಯ ಹೆಗ್ಗಡದೇವನಕೋಟೆ ತಾಲೂಕಿನ ಹಿರೇಹಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಹಿರೇಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 75000.0. ಕಾಮಗಾರಿಯ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕ್ರಿಯ ಯೋಜನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ತಿಳಿದಿಲ್ಲ.
# The local development project is described as "Sc/st kalony Sanitation". It is located in village Bilkerur, of gram panchayat Bilkerur in taluk Bagalkot of district Bagalkote. The estimated cost of the work is Rs. 50000.0. The current status of the work is described as "Technical Approval" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "(SDP)-ಮಾದಿಹಳ್ಳಿ (ತೂಬಿನಕೆರೆ) ಮತ್ತು ಇತರ ಗ್ರಾಮಗಳಿಗೆ PWS ಒದಗಿಸುವುದು. ಕೊಡಿಗೇಹಳ್ಳಿ GP ಕುಣಿಗಲ್‌ನಲ್ಲಿ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ತುಮಕೂರು ಜಿಲ್ಲೆಯ ಕುಣಿಗಲ್ ತಾಲೂಕಿನ ಕೊಡಿಗೇಹಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಮಾದಿಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 2000000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "IMPROVEMENTS TO MINI WATER SUPPLY AT WADERATTI THOTA (4215 ADDITIONAL WATER SUPPLY)". It is located in village Waderahatti, of gram panchayat Waderahatti in taluk Gokak of district Belagavi. The estimated cost of the work is Rs. 500000.0. The current status of the work is described as "Action Plan" and has taken 1 years. This project is Unknown.
# The local development project is described as "Distribution Of Giriraja Birds Under Animal Husbandry". It is located in village Nellurkemraje, of gram panchayat Nelluru Kemraje in taluk Sulya of district Dakshina Kannada. The estimated cost of the work is Rs. 50000.0. The current status of the work is described as "Action Plan" and has taken 1 years. This project is Unknown.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹಣ್ಣಿಕೇರಿ ಗ್ರಾಪಂನಲ್ಲಿ ಪೈಪ್‌ಲೈನ್ ಕಾಮಗಾರಿ ಮಾಡಲಾಗಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಳಗಾವಿ ಜಿಲ್ಲೆಯ ಬೈಲಹೊಂಗಲ ತಾಲೂಕಿನ ಹಣ್ಣಿಕೇರಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಹಣ್ಣಿಕೇರಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 34500.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "Constn.of Basement, Cabin, ಕೊಪ್ಪದಲ್ಲಿ (ಒಳಾಂಗಣ), ಮುಂಡಗೋಡ Tq. (BC ಮಣ್ಣು) ನಿಯಮಿತ ಮಾದರಿಯ 1000 LPH ನ ಸ್ಟೇನ್‌ಲೆಸ್ ಸ್ಟೀಲ್‌ನೊಂದಿಗೆ ಸಂಪೂರ್ಣ ಸ್ವಯಂಚಾಲಿತ WPP" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಉತ್ತರ ಕನ್ನಡ ಜಿಲ್ಲೆಯ ಮುಂಡಗೋಡ ತಾಲೂಕಿನಲ್ಲಿರುವ ಗ್ರಾಮ ಪಂಚಾಯತ್‌ನ ಕೊಪ್ಪ (ಒಳಾಂಗಣ) ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 1020000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "Providing CC ROad and Drain Work at Konaludoddi Village in Kanakapura Taluk". It is located in village Doddamaralawadi, of gram panchayat Doddamaralawadi in taluk Kanakapura of district Ramanagara. The estimated cost of the work is Rs. 1000000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಹಾಲನಾಯಕನಹಳ್ಳಿ ಜಿ.ಪಂ.ನ ಎ.ಕೃಷ್ಣಪ್ಪ ನಗರದ ಗೋವಿಂದರಾಜು ಮನೆಯಿಂದ ದತ್ತಾತ್ರೇಯ ಮನೆವರೆಗೆ 2 ಕಡೆ ಕಾಂಕ್ರೀಟ್ ಚರಂಡಿ ನಿರ್ಮಾಣ ಕಾಮಗಾರಿಗೆ ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆ ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಜಿಲ್ಲೆಯ ಬೆಂಗಳೂರು ಪೂರ್ವ ತಾಲೂಕಿನ ಹಾಲನಾಯಕನಹಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯತ್‌ನ ಹಾಲನಾಯಕನಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 300000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕೆಲಸದ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕಲ್ಲಬಾಳು ಜಿ.ಪಂ. ಆನೇಕಲ್ ತಾಲೂಕಿನ ಕಲ್ಲಬಾಳು ಕೆರೆಗೆ ಸುಧಾರಣೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಜಿಲ್ಲೆಯ ಆನೇಕಲ್ ತಾಲೂಕಿನ ಕಲ್ಲುಬಾಳು ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಕಲ್ಲುಬಾಳು ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 90000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕೆಲಸದ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಮಣ್ಣು ಮತ್ತು ನೀರಿನ ಸಂರಕ್ಷಣೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಕೊಡಗು ಜಿಲ್ಲೆಯ ವಿರಾಜಪೇಟೆ ತಾಲೂಕಿನ ಬಿಟ್ಟಂಗಾಲ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಬಿಟ್ಟಂಗಾಲ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 32500.0. ಕಾಮಗಾರಿಯ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕ್ರಿಯ ಯೋಜನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ತಿಳಿದಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಶಹಾಪುರ ತಾಲೂಕಿನ ಚಟ್ನಳ್ಳಿ, ಡೋರ್ನಳ್ಳಿ, ಹಯ್ಯಲ್ ಬಿ, ಗುಲ್ಸಾರಂ, ಮತ್ತು ಹಲಗೇರಾ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಗಳ 16 ಸಂಖ್ಯೆಗಳಿಗೆ ನೀರು ಸರಬರಾಜು ಸಂಪರ್ಕವನ್ನು ಒದಗಿಸುವುದು" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಯಾದಗಿರಿ ಜಿಲ್ಲೆಯ ಶಹಾಪುರ ತಾಲೂಕಿನ ದೋಹರನಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ದೋಹರನಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 320000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹೊಸಕೋಟೆ Tq ನಲ್ಲಿ ಪ್ಯಾಕೇಜ್ ಸಂಖ್ಯೆ HSK-PRED-PACKAGE-1 ಅಡಿಯಲ್ಲಿ ಟ್ಯಾಂಕ್‌ಗಳ ಪುನಶ್ಚೇತನಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಗ್ರಾಮಾಂತರ ಜಿಲ್ಲೆಯ ಹೊಸಕೋಟೆ ತಾಲೂಕಿನ ನೆಲವಾಗಿಲು ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ತರಬಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 6700000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# The local development project is described as "REVIVAL OF MWSS AT BALANAPALYA HABITATION IN TARUR GP". It is located in village Balanapalya, of gram panchayat Tharur in taluk Sira of district Tumakuru. The estimated cost of the work is Rs. 300000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "PROVIDING BORE WELL WITH HAND PUMP TO ANGANWADI AT SAVALAGI - 317 (ANGANWADI 2013-14)". It is located in village Nandagaon, of gram panchayat Nandagaon in taluk Gokak of district Belagavi. The estimated cost of the work is Rs. 60000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕಾರವಾರ ತಾಲೂಕಿನ ಅಸ್ನೋಟಿ ಜಿಪಿಯಲ್ಲಿರುವ ಮಧೇವಾಡ ಹಬ್ಬಸ್ತಾನ್ ದೇವಸ್ಥಾನದ ಬಳಿ ಟಿಎಫ್‌ಸಿ 08032019 ತೆರೆದ ಬಾವಿಯ ದುರಸ್ತಿ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಉತ್ತರ ಕನ್ನಡ ಜಿಲ್ಲೆಯ ಕಾರವಾರ ತಾಲೂಕಿನ ಅಸ್ನೋಟಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಮಾಧೇವಾಡ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 50000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "Estimate for the Construction of Concrete Drain in 2 sides from Govind Raju house to Dhattatreya house in A.Krishnappa nagara, Halanayakanahalli G.P". It is located in village Halanayakanahalli, of gram panchayat Halanayakanahalli in taluk Bengaluru East of district Bengaluru. The estimated cost of the work is Rs. 300000.0. The current status of the work is described as "Completion Of Work" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಮಳವಳ್ಳಿ tq ಪ್ಲಾಂಟ್‌ನಲ್ಲಿ ಸಹಳ್ಳಿ RO plnt ಗೆ ಸಿಯಾನ್ ಬಾಕ್ಸ್ ಒದಗಿಸುವುದು ಮತ್ತು ಸರಿಪಡಿಸುವುದು" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಮಂಡ್ಯ ಜಿಲ್ಲೆಯ ಮಳವಳ್ಳಿ ತಾಲೂಕಿನ ಅಗಸನಪುರ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಸಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 20000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "Sc/st ಕಾಲೋನಿ ನೈರ್ಮಲ್ಯ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬಾಗಲಕೋಟೆ ಜಿಲ್ಲೆಯ ಬಾಗಲಕೋಟೆ ತಾಲೂಕಿನ ಬಿಲ್ಕೆರೂರು ಗ್ರಾಮ ಪಂಚಾಯತಿಯ ಬಿಲ್ಕೇರೂರ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 50000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ತಾಂತ್ರಿಕ ಅನುಮೋದನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "providing and fixing cion box to sahalli R O plnt in malavalli tq plant". It is located in village Sahalli, of gram panchayat Agasanapura in taluk Malvalli of district Mandya. The estimated cost of the work is Rs. 20000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "construction of cc drain from Sanjiv kumar Hpose to Rangamma House in Mannaekhelli village in Humnabad Taluka". It is located in village Mannaekhelli, of gram panchayat Mannaekhelli in taluk Humnabad of district Bidar. The estimated cost of the work is Rs. 50000.0. The current status of the work is described as "Under Review" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "Rejuvination of Tanks under Package No. HSK-PRED-PACKAGE-1 in Hosakote Tq.". It is located in village Tharabahalli, of gram panchayat Nelavagilu in taluk Hoskote of district Bengaluru Rural. The estimated cost of the work is Rs. 6700000.0. The current status of the work is described as "Under Review" and has taken 1 years. This project is Tendered.
# The local development project is described as "Providing street light in all villages of koutha Gram panchayat in Aurad Taluka". It is located in village Koutha (B), of gram panchayat Koutha (B) in taluk Aurad of district Bidar. The estimated cost of the work is Rs. 76950.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕೆರಾಡಿ ಗ್ರಾ.ಪಂ.ನಲ್ಲಿ ಬೀಡು ಪ್ರದೇಶದಲ್ಲಿ ತೆರೆದ ಬಾವಿ ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಉಡುಪಿ ಜಿಲ್ಲೆಯ ಕುಂದಾಪುರ ತಾಲೂಕಿನ ಕೆರಾಡಿ ಗ್ರಾಮ ಪಂಚಾಯತ್ ವ್ಯಾಪ್ತಿಯ ಕೆರಾಡಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 400000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕೆಲಸದ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ವಡೆರಟ್ಟಿ ತೋಟದಲ್ಲಿ ಮಿನಿ ನೀರು ಪೂರೈಕೆಗೆ ಸುಧಾರಣೆಗಳು (4215 ಹೆಚ್ಚುವರಿ ನೀರು ಸರಬರಾಜು)" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಳಗಾವಿ ಜಿಲ್ಲೆಯ ಗೋಕಾಕ ತಾಲೂಕಿನ ವಡೇರಹಟ್ಟಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ವಡೇರಹಟ್ಟಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 500000.0 ಕಾಮಗಾರಿಯ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕ್ರಿಯ ಯೋಜನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ತಿಳಿದಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಬಿ.ಬಾಗೇವಾಡಿ ಟಕ್ಯುನಲ್ಲಿ ಮುತ್ತಗಿಯಲ್ಲಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿ ಕಟ್ಟಡ ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ವಿಜಯಪುರ ಜಿಲ್ಲೆಯ ಬಸವನ ಬಾಗೇವಾಡಿ ತಾಲೂಕಿನ ಮುತ್ತಗಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಮುತ್ತಗಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 1950000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕುಂದಾಪುರ ತಾಲೂಕಿನ ಕೋಟೇಶ್ವರ ಗ್ರಾ.ಪಂ.ನಲ್ಲಿರುವ ಸರಕಾರಿ ಜೂನಿಯರ್ ಕಾಲೇಜು ಕೋಟೇಶ್ವರಕ್ಕೆ ಪ್ರಸ್ತಾವಿತ ಪಿಯು ಕಾಲೇಜ್ ಕಟ್ಟಡ (2 ತರಗತಿ ಕೊಠಡಿಗಳು, 2 ಟಾಯ್ಲ್ ಬ್ಲಾಕ್) ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಉಡುಪಿ ಜಿಲ್ಲೆಯ ಕುಂದಾಪುರ ತಾಲೂಕಿನ ಕೋಟೇಶ್ವರ ಗ್ರಾಮ ಪಂಚಾಯತ್ ವ್ಯಾಪ್ತಿಯ ಕೋಟೇಶ್ವರ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 5500000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಚಿಂಚಲಕಟ್ಟಿ ಮತ್ತು ಬಾಗಲಕೋಟ ಜಿಲ್ಲೆಯ Bdami TQ ನ ಇತರ 33 ಗ್ರಾಮಗಳಿಗೆ ಒದಗಿಸುವ ನೀರು ಸರಬರಾಜು ಯೋಜನೆ (ಪ್ಯಾಕೇಜ್-3)" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬಾಗಲಕೋಟೆ ಜಿಲ್ಲೆಯ ಬಾದಾಮಿ ತಾಲೂಕಿನ ಫಕೀರಬೂದಿಹಾಳ್ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಚಿಂಚಲಕಟ್ಟಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 85386000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# The local development project is described as "SDP CNR Revival of MWS Scheme from Bore Near Heggotara road at Kalanahundi Village in Chamarajanagara Taluk". It is located in village Kaalanahundi, of gram panchayat Nanjedevanapura in taluk Chamarajanagar of district Chamarajanagara. The estimated cost of the work is Rs. 395000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
#
# False Positives:
# The local development project is described as "Arranging Power supply to water supply to Hulivahana village in Mandya Tq". It is located in village Hulivana, of gram panchayat Hulivana in taluk Mandya of district Mandya. The estimated cost of the work is Rs. 2000000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಜೇವರ್ಗಿ ತಾಲೂಕಿನ ಗುಲ್ಬರ್ಗದ ಕಣ್ಮೇಶ್ವರ ಗ್ರಾಮದ ಭೀಮಣ್ಣ ನಾಟಿಕಾರ್ ಮನೆಯಿಂದ ಮಾಗಂಗೇರ ರಸ್ತೆಯವರೆಗೆ ಚರಂಡಿ ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಕಲಬುರಗಿ ಜಿಲ್ಲೆಯ ಜೇವರ್ಗಿ ತಾಲೂಕಿನ ಮಾಗಣಗೇರಾ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಕಣಮೇಶ್ವರ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 78000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "Drilling of New Borewell (165.mm dia) at Channalli Village Hirekerur Taluk of Haveri District (Primary School Opposite, near Pond)". It is located in village Channalli, of gram panchayat Channalli in taluk Hirekerur of district Haveri. The estimated cost of the work is Rs. 90000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕುಳ್ಳೇಗೌಡನ ಮನೆಯಿಂದ ಪಾಂಡವಪುರದ ದೇಶವಳ್ಳಿಯಲ್ಲಿರುವ ನಾರಾಯಣಸ್ವಾಮಿ ದೇವಸ್ಥಾನದವರೆಗೆ ರಸ್ತೆಯ ಇಂಪ್" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಮಂಡ್ಯ ಜಿಲ್ಲೆಯ ಪಾಂಡವಪುರ ತಾಲೂಕಿನ ತಿರುಮಲಸಾಗರ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ದೇಸುವಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 600000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "Sinking of New Borewell with Handpump near School at Doranalli Village in Shahapur Taluka". It is located in village Doharnalli, of gram panchayat Doharnalli in taluk Shahpur of district Yadgir. The estimated cost of the work is Rs. 90000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಆನೇಕಲ್ ತಾಲೂಕಿನ ಮುಗಳೂರು ಜಿ.ಪಂ.ನ ದೊಡ್ಡತಿಮ್ಮಸಂದ್ರ ಗ್ರಾಮದ ವೆಂಕಟಾಚಲಪ್ಪ ಮನೆಯಿಂದ ಸತೀಶ್ ಮನೆವರೆಗೆ ಸಿಸಿ ರಸ್ತೆ ಒದಗಿಸುವುದು ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆ ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಜಿಲ್ಲೆಯ ನಾನ್ ತಾಲೂಕಿನ ಮುಗುಳೂರು ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ದೊಡ್ಡತಿಮ್ಮಸಂದ್ರ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. nan. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹಿರಿಯೂರು ತಾಲೂಕಿನ ಭರಮಾಪುರ ಗ್ರಾಮದ ಶಾಲೆಯ ಬಳಿಯ ಕೊಳವೆ ಬಾವಿ ಮುಳುಗಡೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಚಿತ್ರದುರ್ಗ ಜಿಲ್ಲೆಯ ಹಿರಿಯೂರು ತಾಲೂಕಿನ ಐಮಂಗಲ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಭರಮಾಪುರ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 27000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕೆಲಸದ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# The local development project is described as "Constuction of 2 Class Rooms & Toilets to Govt PU College, Tubugere in Doddaballapura Taluk". It is located in village Thubugere, of gram panchayat Thubugere in taluk Dodballapur of district Bengaluru Rural. The estimated cost of the work is Rs. 5500000.0. The current status of the work is described as "Under Review" and has taken 1 years. This project is Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಶ್ರೀರಂಗಪಟ್ಟಣ ತಾಲೂಕಿನ O&M Algudu ಗ್ರಾಮದೊಂದಿಗೆ ಸಂಪೂರ್ಣ ಸ್ವಯಂಚಾಲಿತ ಸ್ಟೇನ್‌ಲೆಸ್ ಸ್ಟೀಲ್ ದೇಹ 1000 LPH WPP ಅನ್ನು ಸ್ಥಾಪಿಸುವುದು ಮತ್ತು ನಿಯೋಜಿಸುವುದು" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಮಂಡ್ಯ ಜಿಲ್ಲೆಯ ಶ್ರೀರಂಗಪಟ್ಟಣ ತಾಲೂಕಿನ ತಡಗವಾಡಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಆಲಗೂಡು ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 1200000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಶಹಾಪುರ ತಾಲೂಕಿನ ದೋರನಳ್ಳಿ ಗ್ರಾಮದ ಶಾಲೆಯ ಬಳಿ ಕೈಪಂಪ್‌ನೊಂದಿಗೆ ಹೊಸ ಬೋರ್‌ವೆಲ್ ಮುಳುಗಡೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಯಾದಗಿರಿ ಜಿಲ್ಲೆಯ ಶಹಾಪುರ ತಾಲೂಕಿನ ದೋಹರನಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ದೋಹರನಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 90000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "sinking of bore well near school at bharamapura village in Hiriyur taluk". It is located in village Bharamapura, of gram panchayat Imangala in taluk Hiriyur of district Chitradurga. The estimated cost of the work is Rs. 27000.0. The current status of the work is described as "Completion Of Work" and has taken 1 years. This project is Tendered.
# The local development project is described as "Revival water supply scheme to Raibag Rural Sanadi Tota Habitation". It is located in village Raibag (Rural), of gram panchayat Raibag (Rural) in taluk Raybag of district Belagavi. The estimated cost of the work is Rs. 110000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಹಾವೇರಿ ಜಿಲ್ಲೆಯ ಚನ್ನಳ್ಳಿ ಗ್ರಾಮದ ಹಿರೇಕೆರೂರು ತಾಲೂಕಿನಲ್ಲಿ (165.ಮಿಮೀ ಡಯಾ) ಹೊಸ ಬೋರ್‌ವೆಲ್ ಕೊರೆಯುವುದು (ಪ್ರಾಥಮಿಕ ಶಾಲೆ ಎದುರು, ಕೊಳದ ಹತ್ತಿರ)" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಹಾವೇರಿ ಜಿಲ್ಲೆಯ ಹಿರೇಕೆರೂರು ತಾಲೂಕಿನ ಚನ್ನಳ್ಳಿ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಚನ್ನಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 90000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಮಾಪನ ಹಂತ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕುಣಿಗಲ್ ತಾಲೂಕಿನ ಕನ್ನಗುಣಿ ನಡೆಮಾವಿನಪ್ರ ಗ್ರಾ.ಪಂ.ನಲ್ಲಿರುವ ಅಂಗಡಿಗಳಿಗೆ ವಿದ್ಯುತ್ ವೈರಿಂಗ್ ಅಂದಾಜು" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ತುಮಕೂರು ಜಿಲ್ಲೆಯ ಕುಣಿಗಲ್ ತಾಲೂಕಿನ ನಡೆಮಾವಿನಪುರ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಕನ್ನಗುಣಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 67000.0. ಕಾಮಗಾರಿಯ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಕೆಲಸ ಪೂರ್ಣಗೊಳಿಸುವಿಕೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 6 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಗುಂಡೂರು ಮುಖ್ಯ ರಸ್ತೆಯಲ್ಲಿರುವ ರವಿಕುಮಾರ್ ಮನೆ ಬಳಿ 10 ಕಾಂಕ್ರೀಟ್ ಚಪ್ಪಡಿಗಳ ಸ್ಥಾಪನೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಜಿಲ್ಲೆಯ ಬೆಂಗಳೂರು ಪೂರ್ವ ತಾಲ್ಲೂಕಿನಲ್ಲಿರುವ ಮಂಡೂರು ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ಮಂಡೂರು ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 100000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# The local development project is described as "estimate for electrical wiring to shops at Kannaguni Nademavinapra GP in Kunigal Taluk". It is located in village Kannaguni, of gram panchayat Nademavinapura in taluk Kunigal of district Tumakuru. The estimated cost of the work is Rs. 67000.0. The current status of the work is described as "Completion Of Work" and has taken 6 years. This project is Non-Tendered.
# The local development project is described as "Providing Pathway and Drain to Valgudu Raith Land at Herangadi village in Honnavar Taluk.". It is located in village Harangedi, of gram panchayat Herangadi in taluk Honnavar of district Uttara Kannada. The estimated cost of the work is Rs. 100000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "CONSTRUCTION OF DRAINAGE FROM BHIMANNA NATIKAR HOUSE TO MAGANGERA ROAD IN KANMESHWAR VILLAGE IN JEWARGI TALUKA GULBARGA". It is located in village Kanameshwar, of gram panchayat Magangera in taluk Jevargi of district Kalaburagi. The estimated cost of the work is Rs. 78000.0. The current status of the work is described as "Under Review" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "10 INSTALLATION OF CONCRET SLABS NEAR RAVIKUMAR HOUSE IN GUNDUR MAIN ROAD". It is located in village Manduru, of gram panchayat Manduru in taluk Bengaluru East of district Bengaluru. The estimated cost of the work is Rs. 100000.0. The current status of the work is described as "Under Review" and has taken 1 years. This project is Non-Tendered.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ಕಣ್ಣೂರು ಜಿಪಿ ಬೆಂಗಳೂರು ಪೂರ್ವ ತಾಲೂಕಿನ ಕಾಡುಸೋನಪನಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿರುವ ಪ್ರಾಥಮಿಕ ಆರೋಗ್ಯ ಕೇಂದ್ರದ ದುರಸ್ತಿ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಜಿಲ್ಲೆಯ ಬೆಂಗಳೂರು ಪೂರ್ವ ತಾಲೂಕಿನಲ್ಲಿರುವ ಕಣ್ಣೂರು ಗ್ರಾಮ ಪಂಚಾಯತ್‌ನ ಕಾಡುಸೊನ್ನಪ್ಪನಹಳ್ಳಿ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 100000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಯು ಟೆಂಡರ್ ಆಗಿಲ್ಲ.
# ಸ್ಥಳೀಯ ಅಭಿವೃದ್ಧಿ ಯೋಜನೆಯನ್ನು "ದೊಡ್ಡಬಳ್ಳಾಪುರ ತಾಲೂಕಿನ ತೂಬುಗೆರೆಯ ಸರ್ಕಾರಿ ಪಿಯು ಕಾಲೇಜಿಗೆ 2 ತರಗತಿ ಕೊಠಡಿಗಳು ಮತ್ತು ಶೌಚಾಲಯಗಳ ನಿರ್ಮಾಣ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ. ಇದು ಬೆಂಗಳೂರು ಗ್ರಾಮಾಂತರ ಜಿಲ್ಲೆಯ ದೊಡ್ಡಬಳ್ಳಾಪುರ ತಾಲೂಕಿನ ತೂಬುಗೆರೆ ಗ್ರಾಮ ಪಂಚಾಯಿತಿಯ ತೂಬುಗೆರೆ ಗ್ರಾಮದಲ್ಲಿದೆ. ಕಾಮಗಾರಿಯ ಅಂದಾಜು ವೆಚ್ಚ ರೂ. 5500000.0. ಕೆಲಸದ ಪ್ರಸ್ತುತ ಸ್ಥಿತಿಯನ್ನು "ಪರಿಶೀಲನೆಯಲ್ಲಿದೆ" ಎಂದು ವಿವರಿಸಲಾಗಿದೆ ಮತ್ತು 1 ವರ್ಷಗಳನ್ನು ತೆಗೆದುಕೊಂಡಿದೆ. ಈ ಯೋಜನೆಗೆ ಟೆಂಡರ್ ಆಗಿದೆ.
# The local development project is described as "Imp. of road in Kullegowdana house to Narayanaswamy temple at Deshavalli in pandavapura tq". It is located in village Desuvalli, of gram panchayat Tirumalasagara in taluk Pandavapura of district Mandya. The estimated cost of the work is Rs. 600000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "Providing CC road From Venkatachalappa house to Sathish house, Doddathimmasandra village, Mugalur G.P., Anekal Taluk". It is located in village Doddathimmasandra, of gram panchayat Muguluru in taluk nan of district Bengaluru. The estimated cost of the work is Rs. nan. The current status of the work is described as "Under Review" and has taken 1 years. This project is Non-Tendered.
# The local development project is described as "Providing Water supply to GLPS THUBINA KATTE at Soravanahalli GP in Turuvekere Tq". It is located in village Bommenahalli, of gram panchayat Soravanahalli in taluk Turuvekere of district Tumakuru. The estimated cost of the work is Rs. 19000.0. The current status of the work is described as "Measurement Stage" and has taken 1 years. This project is Non-Tendered.
